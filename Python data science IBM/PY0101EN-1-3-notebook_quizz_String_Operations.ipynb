# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h3 align=center>Slicing </h3>

# %%
A= "joan"
B= ["joan"]
amigos = ["luis", "carlos", "eduardo"]
#print(amigos + A)
print(amigos + B)
# Out:
# ['luis', 'carlos', 'eduardo', 'joan']

# %%
v=10.478
print ("la velocidad es %3.4f \n" % v)
print ("la velocidad es %3.4d \n" % v)
print ("la velocidad es %3.4c \n" %"A")
print ("la velocidad es %3.4g \n" % v)
print ("la velocidad es %3.4e \n" % v)
# Out:
# la velocidad es 10.4780
#
# la velocidad es 0010
#
# la velocidad es   A
#
# la velocidad es 10.48
#
# la velocidad es 1.0478e+01

# %% [markdown]
# Use slicing to find the first four elements of the following string:

# %%
Letters="ABCDEFGHIJK"
Letters[0:4]
# Out:
# 'ABCD'

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# Letters[0:4]
# ```
#
# </details>

# %% [markdown]
# <h3 align=center>Strides are Good </h3>

# %% [markdown]
# Use a stride value of two on the following string :

# %%
Good="GsoAo+d"
Good[::2]
# Out:
# 'Good'

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# Good[::2]
# ```
#
# </details>

# %% [markdown]
# <h3 align=center>uppercase to UPPERCASE </h3>

# %% [markdown]
# Convert the following string to uppercase using the method <code>upper()</code>

# %%
"uppercase".upper()
# Out:
# 'UPPERCASE'

# %%
a="1"
b="2"
c = a + b
c
# Out:
# '12'

# %%
T=int(c)
type(T)
T
# Out:
# 12

# %%
e = 'clocrkr1e1c1t'
e[::2]
# Out:
# 'correct'

# %%
A=[0,1,2,3,3]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# "uppercase".upper()
# ```
#
# </details>

# %% [markdown]
# <hr>
#
# <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
